# %% [markdown]
# # Hausaufgabe 5
#
# ## Integration einer Bewegungsgleichung: Freier Fall - Wiederholung
#
# In dieser Aufgabe werden wir erneut die Bewegungsgleichung des freien Falls numerisch mit dem Euler Verfahren lösen. Die Bewegungsgleichung hat die Form:
# \begin{equation}\tag{1}
#  \ddot x = \frac{\mathrm{d}^2x}{\mathrm{d}t^2}= a
# \end{equation}
#
# Dieses Mal soll die Bewegungsgleichung nicht "per Hand" sondern rekursiv mittels einer Schleife gelöst werden.

# %% [markdown]
# ## 1. Integration mit Schleife
#
# **a)** Lösen Sie erneut Gleichung (1) für fünf Zeitschritte $\Delta t = 0.1$, indem Sie die Gleichungen (3) und (4) für die Anfangswerte $x_0=x\left(t=0\right) = 2$ und $v_0=v\left(t=0\right) = 1$ numerisch mit Hilfe einer Schleife integrieren. Dabei soll $a=-9.81$ sein. Speichern Sie die numerisch berechneten Positionen in einer Liste indem Sie `append()` benutzen.
#
# Als Erinerrung:
#
# \begin{equation} \tag{2}
# x\!\left( t \right) = x_0 + v_0 t + \frac{1}{2} a t^2.
# \end{equation}
#
# \begin{align}\tag{3}
#         x\left(t+\Delta t \right) &= x\left(t\right) + v\left(t\right) \Delta t \\
#         v\left(t+\Delta t \right) &= v\left(t\right) + a\Delta t \tag{4}
#     \end{align}

# %%
#Definition der Variablen
a=-9.81
k=2
j=1

x = [2] #Liste für Position
v = [1] #Liste für Geschwindigkeit
for i in range(4):  # loop 
    k = k + j*0.1 #Gleichung für Positionen
    j = j + a*0.1 #Gleichung für Geschwindigkeiten
    x.append(k) #Ergebnis der Rechnung wird an Positionsiste angehangen
    v.append(j) #Ergebnis der Rechnung wird an Geschwindigkeitsliste angehangen
    
print("x=", x,"v=", v) #Listen werden ausgegeben
# Out:
# x= [2, 2.1, 2.1019, 2.0057, 1.8114] v= [1, 0.018999999999999906, -0.9620000000000002, -1.9430000000000003, -2.9240000000000004]

# %% [markdown]
# **b)** Plotten Sie diese Positionen in einem Diagramm mit der Bahnkurve (Gleichung (2)). Benutzen Sie das mit `ax.scatter()` erweiterte Grundgerüst von `helpPlotScatter.ipynb`.

# %%
import numpy as np
import matplotlib.pyplot as plt

#Definition der Variablen
x0 = 2
v0 = 1
dt =0.1

t = np.linspace(0, 4*dt, 20) #Zeit für analytische Läsung
xAnalytic = x0 + v0 * t + 0.5 * a * t**2 #Gleichung für analytische Lösung

tNumeric = np.linspace(0, 4*dt,5) #Zeit für numerische Lösung

fig, ax = plt.subplots()

ax.set_title("Geradlinige Beschleunigung")  # Titel
ax.plot(t, xAnalytic, label='analytische Lösung')  #analytische Lösung
ax.scatter(tNumeric, x, label='numerische Lösung') #numerische Lösung
ax.set_xlabel("Zeit $t$") #Achsenbeschriftungen
ax.set_ylabel("Position $x$")

plt.legend(loc=3) #Legende unten links wird angezeigt
plt.show()

# %% [markdown]
# ## 2. Variation des Zeitschrittes
#
# Sie sollten nun die Abbildung aus Hausaufgabe 3 reproduziert haben.
#
# **a)** Wiederholen Sie Aufgabe 1 mit einem Zeitschritt $\Delta t = 0.005$. Achten Sie darauf, dass die Integrationszeit gleich bleibt! Da Sie nun sehr viele Werte erzeugt haben, ist es sinnvoller die numerische Lösung ebenfalls in einem Linienplot mit `ax.plot()` darzustellen.

# %%
#Definition der Variablen
a=-9.81
k=2
j=1

x2 = [2] #Positionsliste für dt=0.05
for i in range(8):  # loop 
    k = k + j*0.05 #Gleichung für Positionen
    j = j + a*0.05 #Gleichung für Geschewindigkeiten
    x2.append(k) # Ergebnis der Rechnung wird an PositionsListe angehängt
    
print(x2) #Liste wird ausgegeben

import numpy as np
import matplotlib.pyplot as plt

#Definition der Variablen
x0 = 2
v0 = 1
dt =0.1
dt2=0.05

t = np.linspace(0, 4*dt, 20) #Zeit für analytische Lösung
xAnalytic = x0 + v0 * t + 0.5 * a * t**2 #Gleichung für analytische Lösung

tNumeric = np.linspace(0, 4*dt,5) #Zeit fürnumerische Lösung dt=0.1
tNumeric2 = np.linspace(0, 8*dt2,9) #Zeit für numerische Lösung dt=0.05

fig, ax = plt.subplots()

ax.set_title("Geradlinige Beschleunigung")  # Titel
ax.plot(t, xAnalytic, label='analytische Lösung')  #analytische Lösung
ax.scatter(tNumeric, x, label='numerische Lösung $dt=0.1$') #numerische Lösung für dt=0.1
ax.scatter(tNumeric2, x2, label='numerische Lösung $dt=0.05$') #numerische Lösung für dt=0.05
ax.set_xlabel("Zeit $t$") #Achsenbeschriftungen
ax.set_ylabel("Position $x$")

plt.legend(loc=3) #Legende unten links wird angezeigt
plt.show()
# Out:
# [2, 2.05, 2.075475, 2.076425, 2.05285, 2.00475, 1.932125, 1.834975, 1.7133]

# %% [markdown]
# **b)** Berechnen Sie die quadratische Abweichung $\mathrm{SE}\left(t\right)$ zwischen der numerischen und analytischen Lösung abhängig vom Zeitschritt:
#    $$
#    \mathrm{SE}\left(t\right) = \left(x_{\mathrm{numerisch}}\left(t\right) - x_\mathrm{analytisch}\left(t\right)\right) ^2 \, .
#    $$
# Plotten Sie die quadratische Abweichung gegen die Zeit. Benutzen Sie geeignete Beschriftungen!
#
# Beschreiben Sie kurz, was Sie beobachten.

# %%
t = np.linspace(0, 4*dt, 5)
xAnalytic = x0 + v0 * t + 0.5 * a * t**2 #x_analytisch für dt=0.1

t2 = np.linspace(0,8*dt2, 9)
xAnalytic2 = x0 + v0 * t2 + 0.5 * a * t2**2 #x_analytisch für dt=0.05

SE = (x-xAnalytic)**2 #quadratische Abweichung für dt=0.1
SE2 = (x2-xAnalytic2)**2 #quadratische Abweichung für dt=0.05

SE1= np.array(SE)
SE05= np.array(SE2)
print("SE für dt=0.1", SE1, "SE für dt=0.05", SE05)

fig, ax = plt.subplots()

ax.set_title("Quadratische Abweichung")  # Titel
ax.scatter(t, SE, label='$SE$ für $dt=0.1$') #quadratische Abweichung für dt=0.1 wird geplottet
ax.scatter(t2, SE2, label='$SE$ für $dt=0.05$') #quadratische Abweichung für dt=0.05 wird geplottet
ax.set_xlabel("Zeit $t$") #Achsenbeschriftungen
ax.set_ylabel("Quadratische Abweichung $SE$")

plt.legend(loc=2) #Legende wird oben links angezeigt
plt.show()
# Out:
# SE für dt=0.1 [0.         0.0024059  0.00962361 0.02165312 0.03849444] SE für dt=0.05 [0.         0.00015037 0.00060148 0.00135332 0.0024059  0.00375922
#  0.00541328 0.00736808 0.00962361]

# %%
#Für größere Zeiten nimmt die quadratische Abweichung stark zu.
#Für kleine Zeiten stimmen die quadratischen Abweichungen annähernd überein.
#Mit größeren Zeiten wird auch der Unterschied zwischen den quadratischen Abweichungen größer.
#Für die 2. numerische Integration mit kleineren Zeitschritt ist die quadratische Abweichung deutlich geringer.
