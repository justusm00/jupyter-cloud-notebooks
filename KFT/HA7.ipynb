# %%
import numpy as np
import matplotlib.pyplot as plt

a = 1
b = 1
phi = np.pi/2
w = 1
k = 1

def E(z,t):
    Ex = a * np.cos(k*z  -w *t)
    Ey = b * np.cos(k*z  -w *t + phi)
    return Ex, Ey

t = np.linspace(0,10,100)
                
plt.plot(E(0,t)[0],E(0,t)[1])
