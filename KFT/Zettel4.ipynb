# %%
import numpy as np
import matplotlib.pyplot as plt

eps0=8.854*1e-12

def phi(r,alpha,Q,q): ##exakt
    return 1/(4*np.pi*eps0) *(Q/np.sqrt(r**2+1-2*r*np.cos(alpha))+ (q-Q)/np.sqrt(r**2+1+2*r*np.cos(alpha)))


def phi_m(r,alpha,Q,q):
    return 1/(4*np.pi*eps0) * (q/r + np.cos(alpha)*(2*Q-q)/r**2)

alpha = np.linspace(0,2*np.pi,100)

##q = 0

plt.figure(dpi = 200)
plt.title("q=0, r=1.5")
plt.grid()
plt.xlabel("Winkel")
plt.ylabel("$\Phi$")
plt.plot(alpha,phi(1.5,alpha,10,0),linewidth= 1,label = "Exakt")
plt.plot(alpha,phi_m(1.5,alpha,10,0),linewidth= 1, label = "Multipol")
plt.legend(loc = "upper right")
plt.savefig("4_3e_1.png")

plt.figure(dpi = 200)
plt.title("q=0, r=5")
plt.grid()
plt.xlabel("Winkel")
plt.ylabel("$\Phi$")
plt.plot(alpha,phi(5,alpha,10,0),linewidth= 1,label = "Exakt")
plt.plot(alpha,phi_m(5,alpha,10,0),linewidth= 1, label = "Multipol")
plt.legend(loc = "upper right")
plt.savefig("4_3e_2.png")

plt.figure(dpi = 200)
plt.title("q=0, r=50")
plt.grid()
plt.xlabel("Winkel")
plt.ylabel("$\Phi$")
plt.plot(alpha,phi(50,alpha,10,0),linewidth= 1,label = "Exakt")
plt.plot(alpha,phi_m(50,alpha,10,0),linewidth= 1, label = "Multipol")
plt.legend(loc = "upper right")
plt.savefig("4_3e_3.png")


### q = Q/2
plt.figure(dpi = 200)
plt.title("q=Q/2, r=1.5")
plt.grid()
plt.xlabel("Winkel")
plt.ylabel("$\Phi$")
plt.plot(alpha,phi(1.5,alpha,10,5),linewidth= 1,label = "Exakt")
plt.plot(alpha,phi_m(1.5,alpha,10,5),linewidth= 1, label = "Multipol")
plt.legend(loc = "upper right")
plt.savefig("4_3e_4.png")

plt.figure(dpi = 200)
plt.title("q=Q/2, r=5")
plt.grid()
plt.xlabel("Winkel")
plt.ylabel("$\Phi$")
plt.plot(alpha,phi(5,alpha,10,5),linewidth= 1,label = "Exakt")
plt.plot(alpha,phi_m(5,alpha,10,5),linewidth= 1, label = "Multipol")
plt.legend(loc = "upper right")
plt.savefig("4_3e_5.png")

plt.figure(dpi = 200)
plt.title("q=Q/2, r=50")
plt.grid()
plt.xlabel("Winkel")
plt.ylabel("$\Phi$")
plt.plot(alpha,phi(50,alpha,10,5),linewidth= 1,label = "Exakt")
plt.plot(alpha,phi_m(50,alpha,10,5),linewidth= 1, label = "Multipol")
plt.legend(loc = "upper right")
plt.savefig("4_3e_6.png")
