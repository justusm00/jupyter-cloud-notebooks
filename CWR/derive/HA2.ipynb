# %%
import numpy as np
import matplotlib.pyplot as plt


delta = np.loadtxt("derive.txt", usecols = 0)
errs = np.loadtxt("derive.txt", usecols = 1)



plt.figure(dpi=400)
plt.title("error")
plt.grid()
plt.ylabel("Error")
plt.xlabel("$\delta$")
plt.plot(np.log10(delta),np.log10(errs),lw=1)
