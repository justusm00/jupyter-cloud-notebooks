# %%
import numpy as np
import matplotlib.pyplot as plt


t = np.loadtxt("time.dat")
pos = np.loadtxt("position.dat")
pos = np.transpose(pos)

N = 30 
print(pos[29])




plt.figure(dpi = 200)
plt.grid()
plt.title("oscillators go brrr")
for i in range(N):
    plt.plot(t,pos[i],'k', lw = 0.5)
plt.savefig("plot_gsl.pdf")
# Out:
# [29.       29.       29.       ... 29.231633 29.250203 29.263368]
