# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Kalibrirung des Stromintegrators
R_i = 10000 # Eingangswiderstand des Stromintegrators in Ohm
R_1 = 1000 # Widerstand in Ohm
R_2 = 3.3 # Widerstand in Ohm
U = 2.000 # Spannung des Eichgenerators/Zeitschalters

R_ges = R_1 + R_2*R_i/(R_2+R_i)
I = U/R_ges # Strom in mA
U_i = I*R_2*R_i/(R_2+R_i) # Spannung am Stromintegrators in V
I_i = U_i/R_i # Spannung durch den Stromintegrators in A
I_i = I_i*1000**2 # Strom durch den Stromintegrators in 10^-6 A

n = 10 # Anzahl der Messwerte

t00 = 50 # Eichzeit in ms
t01 = 100 # Eichzeit in ms
t02 = 150 # Eichzeit in ms
t03 = 200 # Eichzeit in ms
t04 = 250 # Eichzeit in ms
t05 = 300 # Eichzeit in ms
t06 = 350 # Eichzeit in ms
t07 = 400 # Eichzeit in ms
t08 = 450 # Eichzeit in ms
t09 = 500 # Eichzeit in ms
t_fehler = 1 # Fehler in ms

q_mess_00 = 79 # Gemessene Ladung in Skalenteilen
q_mess_01 = 156 # Gemessene Ladung in Skalenteilen
q_mess_02 = 234 # Gemessene Ladung in Skalenteilen
q_mess_03 = 311 # Gemessene Ladung in Skalenteilen
q_mess_04 = 387 # Gemessene Ladung in Skalenteilen
q_mess_05 = 463 # Gemessene Ladung in Skalenteilen
q_mess_06 = 542 # Gemessene Ladung in Skalenteilen
q_mess_07 = 619 # Gemessene Ladung in Skalenteilen
q_mess_08 = 695 # Gemessene Ladung in Skalenteilen
q_mess_09 = 774 # Gemessene Ladung in Skalenteilen

q_calc_00 = I_i*t00 # Eichladung in 10^-9 Coulomb
q_calc_01 = I_i*t01 # Eichladung in 10^-9 Coulomb
q_calc_02 = I_i*t02 # Eichladung in 10^-9 Coulomb
q_calc_03 = I_i*t03 # Eichladung in 10^-9 Coulomb
q_calc_04 = I_i*t04 # Eichladung in 10^-9 Coulomb
q_calc_05 = I_i*t05 # Eichladung in 10^-9 Coulomb
q_calc_06 = I_i*t06 # Eichladung in 10^-9 Coulomb
q_calc_07 = I_i*t07 # Eichladung in 10^-9 Coulomb
q_calc_08 = I_i*t08 # Eichladung in 10^-9 Coulomb
q_calc_09 = I_i*t09 # Eichladung in 10^-9 Coulomb

q_calc_00_fehler = I_i*t_fehler # Fehler in 10^-6 Coulomb
q_calc_01_fehler = I_i*t_fehler  # Fehler in 10^-6 Coulomb
q_calc_02_fehler = I_i*t_fehler  # Fehler in 10^-6 Coulomb
q_calc_03_fehler = I_i*t_fehler  # Fehler in 10^-6 Coulomb
q_calc_04_fehler = I_i*t_fehler  # Fehler in 10^-6 Coulomb
q_calc_05_fehler = I_i*t_fehler  # Fehler in 10^-6 Coulomb
q_calc_06_fehler = I_i*t_fehler  # Fehler in 10^-6 Coulomb
q_calc_07_fehler = I_i*t_fehler  # Fehler in 10^-6 Coulomb
q_calc_08_fehler = I_i*t_fehler  # Fehler in 10^-6 Coulomb
q_calc_09_fehler = I_i*t_fehler  # Fehler in 10^-6 Coulomb

# Trage q_calc auf q_mess auf
# Einfache Lineare Regression, vergleiche Seite 44 Prakikumsanleitung

Summe_xi = q_mess_00 + q_mess_01 + q_mess_02 + q_mess_03 + q_mess_04 + q_mess_05 + q_mess_06 + q_mess_07 + q_mess_08 + q_mess_09
Summe_yi = q_calc_00 + q_calc_01 + q_calc_02 + q_calc_03 + q_calc_04 + q_calc_05 + q_calc_06 + q_calc_07 + q_calc_08 + q_calc_09
Summe_xi_yi = q_mess_00*q_calc_00 + q_mess_01*q_calc_01 + q_mess_02*q_calc_02 + q_mess_03*q_calc_03 + q_mess_04*q_calc_04 + q_mess_05*q_calc_05 + q_mess_06*q_calc_06 + q_mess_07*q_calc_07 + q_mess_08*q_calc_08 + q_mess_09*q_calc_09
Summe_xi_quadrat = q_mess_00**2 + q_mess_01**2 + q_mess_02**2 + q_mess_03**2 + q_mess_04**2 + q_mess_05**2 + q_mess_06**2 + q_mess_07**2 + q_mess_08**2 + q_mess_09**2
Summe_yi_quadrat = q_calc_00**2 + q_calc_01**2 + q_calc_02**2 + q_calc_03**2 + q_calc_04**2 + q_calc_05**2 + q_calc_06**2 + q_calc_07**2 + q_calc_08**2 + q_calc_09**2

m = (n*Summe_xi_yi-Summe_xi*Summe_yi)/(n*Summe_xi_quadrat-Summe_xi**2) # Steigung  m
b = (Summe_xi_quadrat*Summe_yi-Summe_xi*Summe_xi_yi)/(n*Summe_xi_quadrat-Summe_xi**2) # y-Achsenabschnitt b
Summe_fehler_quadrat = (q_calc_00-b-m*q_mess_00)**2 + (q_calc_01-b-m*q_mess_01)**2 + (q_calc_02-b-m*q_mess_02)**2 + (q_calc_03-b-m*q_mess_03)**2 + (q_calc_04-b-m*q_mess_04)**2 + (q_calc_05-b-m*q_mess_05)**2 + (q_calc_06-b-m*q_mess_06)**2 + (q_calc_07-b-m*q_mess_07)**2 + (q_calc_08-b-m*q_mess_08)**2 + (q_calc_09-b-m*q_mess_09)**2
m_fehler = (n*Summe_fehler_quadrat)/((n-2)*(n*Summe_xi_quadrat-Summe_xi**2))
m_fehler = np.sqrt(m_fehler)
b_fehler = (Summe_xi_quadrat*Summe_fehler_quadrat)/((n-2)*(n*Summe_xi_quadrat-Summe_xi**2))
b_fehler = np.sqrt(b_fehler)
r = n*Summe_xi_yi-Summe_xi*Summe_yi
r = r/(np.sqrt((n*Summe_xi_quadrat-Summe_xi**2)))
r = r/(np.sqrt((n*Summe_yi_quadrat-Summe_yi**2)))

print("Strom durch den Stromintegrators in 10^-6 A:", I_i)

print(" ") # Leerzeile

# Für den Plot01 via Gnuplot

print("Für V14_plot01.dat via Gnuplot:")

print(" ") # Leerzeile

print("# q_mess[skt] q_calc[nC] q_calc_fehler[nC]")

print(q_mess_00, q_calc_00, q_calc_00_fehler)
print(q_mess_01, q_calc_01, q_calc_01_fehler)
print(q_mess_02, q_calc_02, q_calc_02_fehler)
print(q_mess_03, q_calc_03, q_calc_03_fehler)
print(q_mess_04, q_calc_04, q_calc_04_fehler)
print(q_mess_05, q_calc_05, q_calc_05_fehler)
print(q_mess_06, q_calc_06, q_calc_06_fehler)
print(q_mess_07, q_calc_07, q_calc_07_fehler)
print(q_mess_08, q_calc_08, q_calc_08_fehler)
print(q_mess_09, q_calc_09, q_calc_09_fehler)

# Nur zur Kontrolle

print(" ") # Leerzeile

print("Werte zur linearen Regression:")

print("m:", m)
print("m_fehler:", m_fehler)
print("b:", b)
print("b_fehler:", b_fehler)
print("r:", r)

# m ist die Eichkonstante in 10^-6 Coulomb/Skt
# Q(C) = m*Q(Skt) + b

#m_eich = m
#m_eich_fehler = m_fehler
#b_eich = b
#b_eich_fehler = b_fehler

# Ende der Kalibration
# Out:
# Strom durch den Stromintegrators in 10^-6 A: 0.6576128652989648
#
# Für V14_plot01.dat via Gnuplot:
#
# # q_mess[skt] q_calc[nC] q_calc_fehler[nC]
# 79 32.88064326494824 0.6576128652989648
# 156 65.76128652989648 0.6576128652989648
# 234 98.64192979484471 0.6576128652989648
# 311 131.52257305979296 0.6576128652989648
# 387 164.4032163247412 0.6576128652989648
# 463 197.28385958968943 0.6576128652989648
# 542 230.16450285463768 0.6576128652989648
# 619 263.0451461195859 0.6576128652989648
# 695 295.92578938453414 0.6576128652989648
# 774 328.8064326494824 0.6576128652989648
#
# Werte zur linearen Regression:
# m: 0.4264458359499401
# m_fehler: 0.0005105666921136824
# b: -0.8223881574592883
# b_fehler: 0.245136781804717
# r: 0.999994266319901

# %%
# Begin Auswertung Teil 1

d_ind = 0.059 # Durchmesser der Induktionspule in Metern
r_ind = d_ind/2 # Radius der Induktionspule in Metern
A = np.pi*r_ind**2 # Querschnittsfläche der Spule in m^2
N = 369 # Windungszahl der Spule

q_mess_fehler = 0.5 # In Skalenteilen

q_mess10 = 263 # In Skalenteilen # 22,5 cm
q_mess11 = 264 # In Skalenteilen
q_mess12 = 264 # In Skalenteilen
q_mess13 = 262 # In Skalenteilen
q_mess14 = 258 # In Skalenteilen
q_mess15 = 257 # In Skalenteilen
q_mess16 = 253 # In Skalenteilen
q_mess17 = 247 # In Skalenteilen
q_mess18 = 235 # In Skalenteilen
q_mess19 = 217 # In Skalenteilen
q_mess20 = 192 # In Skalenteilen
q_mess21 = 151 # In Skalenteilen
q_mess22 = 108 # In Skalenteilen
q_mess23 = 73 # In Skalenteilen
q_mess24 = 49 # In Skalenteilen
q_mess25 = 36 # In Skalenteilen
q_mess26 = 24 # In Skalenteilen
q_mess27 = 15 # In Skalenteilen
q_mess28 = 6 # In Skalenteilen
q_mess29 = 7 # In Skalenteilen # 60,5 cm

q_calc10 = m*q_mess10 + b # In 10^-9 C
q_calc10_fehler = np.sqrt((m_fehler*q_mess10)**2 + (m*q_mess_fehler)**2 + b_fehler**2) # In 10^-9 C
q_calc11 = m*q_mess11 + b # In 10^-9 C
q_calc11_fehler = np.sqrt((m_fehler*q_mess11)**2 + (m*q_mess_fehler)**2 + b_fehler**2) # In 10^-9 C
q_calc12 = m*q_mess12 + b # In 10^-9 C
q_calc12_fehler = np.sqrt((m_fehler*q_mess12)**2 + (m*q_mess_fehler)**2 + b_fehler**2) # In 10^-9 C
q_calc13 = m*q_mess13 + b # In 10^-9 C
q_calc13_fehler = np.sqrt((m_fehler*q_mess13)**2 + (m*q_mess_fehler)**2 + b_fehler**2) # In 10^-9 C
q_calc14 = m*q_mess14 + b # In 10^-9 C
q_calc14_fehler = np.sqrt((m_fehler*q_mess14)**2 + (m*q_mess_fehler)**2 + b_fehler**2) # In 10^-9 C
q_calc15 = m*q_mess15 + b # In 10^-9 C
q_calc15_fehler = np.sqrt((m_fehler*q_mess15)**2 + (m*q_mess_fehler)**2 + b_fehler**2) # In 10^-9 C
q_calc16 = m*q_mess16 + b # In 10^-9 C
q_calc16_fehler = np.sqrt((m_fehler*q_mess16)**2 + (m*q_mess_fehler)**2 + b_fehler**2) # In 10^-9 C
q_calc17 = m*q_mess17 + b # In 10^-9 C
q_calc17_fehler = np.sqrt((m_fehler*q_mess17)**2 + (m*q_mess_fehler)**2 + b_fehler**2) # In 10^-9 C
q_calc18 = m*q_mess18 + b # In 10^-9 C
q_calc18_fehler = np.sqrt((m_fehler*q_mess18)**2 + (m*q_mess_fehler)**2 + b_fehler**2) # In 10^-9 C
q_calc19 = m*q_mess19 + b # In 10^-9 C
q_calc19_fehler = np.sqrt((m_fehler*q_mess19)**2 + (m*q_mess_fehler)**2 + b_fehler**2) # In 10^-9 C
q_calc20 = m*q_mess20 + b # In 10^-9 C
q_calc20_fehler = np.sqrt((m_fehler*q_mess20)**2 + (m*q_mess_fehler)**2 + b_fehler**2) # In 10^-9 C
q_calc21 = m*q_mess21 + b # In 10^-9 C
q_calc21_fehler = np.sqrt((m_fehler*q_mess21)**2 + (m*q_mess_fehler)**2 + b_fehler**2) # In 10^-9 C
q_calc22 = m*q_mess22 + b # In 10^-9 C
q_calc22_fehler = np.sqrt((m_fehler*q_mess22)**2 + (m*q_mess_fehler)**2 + b_fehler**2) # In 10^-9 C
q_calc23 = m*q_mess23 + b # In 10^-9 C
q_calc23_fehler = np.sqrt((m_fehler*q_mess23)**2 + (m*q_mess_fehler)**2 + b_fehler**2) # In 10^-9 C
q_calc24 = m*q_mess24 + b # In 10^-9 C
q_calc24_fehler = np.sqrt((m_fehler*q_mess24)**2 + (m*q_mess_fehler)**2 + b_fehler**2) # In 10^-9 C
q_calc25 = m*q_mess25 + b # In 10^-9 C
q_calc25_fehler = np.sqrt((m_fehler*q_mess25)**2 + (m*q_mess_fehler)**2 + b_fehler**2) # In 10^-9 C
q_calc26 = m*q_mess26 + b # In 10^-9 C
q_calc26_fehler = np.sqrt((m_fehler*q_mess26)**2 + (m*q_mess_fehler)**2 + b_fehler**2) # In 10^-9 C
q_calc27 = m*q_mess27 + b # In 10^-9 C
q_calc27_fehler = np.sqrt((m_fehler*q_mess27)**2 + (m*q_mess_fehler)**2 + b_fehler**2) # In 10^-9 C
q_calc28 = m*q_mess28 + b # In 10^-9 C
q_calc28_fehler = np.sqrt((m_fehler*q_mess28)**2 + (m*q_mess_fehler)**2 + b_fehler**2) # In 10^-9 C
q_calc29 = m*q_mess29 + b # In 10^-9 C
q_calc29_fehler = np.sqrt((m_fehler*q_mess29)**2 + (m*q_mess_fehler)**2 + b_fehler**2) # In 10^-9 C

# B = R_i*Q/(N*A)

B10 = R_i*q_calc10/(N*A*10**6) # In 10^-3 Tesla
B10_fehler = R_i*q_calc10_fehler/(N*A*10**6) # In 10^-3 Tesla
B11 = R_i*q_calc11/(N*A*10**6) # In 10^-3 Tesla
B11_fehler = R_i*q_calc11_fehler/(N*A*10**6) # In 10^-3 Tesla
B12 = R_i*q_calc12/(N*A*10**6) # In 10^-3 Tesla
B12_fehler = R_i*q_calc12_fehler/(N*A*10**6) # In 10^-3 Tesla
B13 = R_i*q_calc13/(N*A*10**6) # In 10^-3 Tesla
B13_fehler = R_i*q_calc13_fehler/(N*A*10**6) # In 10^-3 Tesla
B14 = R_i*q_calc14/(N*A*10**6) # In 10^-3 Tesla
B14_fehler = R_i*q_calc14_fehler/(N*A*10**6) # In 10^-3 Tesla
B15 = R_i*q_calc15/(N*A*10**6) # In 10^-3 Tesla
B15_fehler = R_i*q_calc15_fehler/(N*A*10**6) # In 10^-3 Tesla
B16 = R_i*q_calc16/(N*A*10**6) # In 10^-3 Tesla
B16_fehler = R_i*q_calc16_fehler/(N*A*10**6) # In 10^-3 Tesla
B17 = R_i*q_calc17/(N*A*10**6) # In 10^-3 Tesla
B17_fehler = R_i*q_calc17_fehler/(N*A*10**6) # In 10^-3 Tesla
B18 = R_i*q_calc18/(N*A*10**6) # In 10^-3 Tesla
B18_fehler = R_i*q_calc18_fehler/(N*A*10**6) # In 10^-3 Tesla
B19 = R_i*q_calc19/(N*A*10**6) # In 10^-3 Tesla
B19_fehler = R_i*q_calc19_fehler/(N*A*10**6) # In 10^-3 Tesla
B20 = R_i*q_calc20/(N*A*10**6) # In 10^-3 Tesla
B20_fehler = R_i*q_calc20_fehler/(N*A*10**6) # In 10^-3 Tesla
B21 = R_i*q_calc21/(N*A*10**6) # In 10^-3 Tesla
B21_fehler = R_i*q_calc21_fehler/(N*A*10**6) # In 10^-3 Tesla
B22 = R_i*q_calc22/(N*A*10**6) # In 10^-3 Tesla
B22_fehler = R_i*q_calc22_fehler/(N*A*10**6) # In 10^-3 Tesla
B23 = R_i*q_calc23/(N*A*10**6) # In 10^-3 Tesla
B23_fehler = R_i*q_calc23_fehler/(N*A*10**6) # In 10^-3 Tesla
B24 = R_i*q_calc24/(N*A*10**6) # In 10^-3 Tesla
B24_fehler = R_i*q_calc24_fehler/(N*A*10**6) # In 10^-3 Tesla
B25 = R_i*q_calc25/(N*A*10**6) # In 10^-3 Tesla
B25_fehler = R_i*q_calc25_fehler/(N*A*10**6) # In 10^-3 Tesla
B26 = R_i*q_calc26/(N*A*10**6) # In 10^-3 Tesla
B26_fehler = R_i*q_calc26_fehler/(N*A*10**6) # In 10^-3 Tesla
B27 = R_i*q_calc27/(N*A*10**6) # In 10^-3 Tesla
B27_fehler = R_i*q_calc27_fehler/(N*A*10**6) # In 10^-3 Tesla
B28 = R_i*q_calc28/(N*A*10**6) # In 10^-3 Tesla
B28_fehler = R_i*q_calc28_fehler/(N*A*10**6) # In 10^-3 Tesla
B29 = R_i*q_calc29/(N*A*10**6) # In 10^-3 Tesla
B29_fehler = R_i*q_calc29_fehler/(N*A*10**6) # In 10^-3 Tesla

B_Pos_fehler = 0.005 # 0,5 cm in Metern

B10_pos = (22.5-22.5)/100 # Position relativ zur Mitte in m
B11_pos = (24.5-22.5)/100 # Position relativ zur Mitte in m
B12_pos = (26.5-22.5)/100 # Position relativ zur Mitte in m
B13_pos = (28.5-22.5)/100 # Position relativ zur Mitte in m
B14_pos = (30.5-22.5)/100 # Position relativ zur Mitte in m
B15_pos = (32.5-22.5)/100 # Position relativ zur Mitte in m
B16_pos = (34.5-22.5)/100 # Position relativ zur Mitte in m
B17_pos = (36.5-22.5)/100 # Position relativ zur Mitte in m
B18_pos = (38.5-22.5)/100 # Position relativ zur Mitte in m
B19_pos = (40.5-22.5)/100 # Position relativ zur Mitte in m
B20_pos = (42.5-22.5)/100 # Position relativ zur Mitte in m
B21_pos = (44.5-22.5)/100 # Position relativ zur Mitte in m
B22_pos = (46.5-22.5)/100 # Position relativ zur Mitte in m
B23_pos = (48.5-22.5)/100 # Position relativ zur Mitte in m
B24_pos = (50.5-22.5)/100 # Position relativ zur Mitte in m
B25_pos = (52.5-22.5)/100 # Position relativ zur Mitte in m
B26_pos = (54.5-22.5)/100 # Position relativ zur Mitte in m
B27_pos = (56.5-22.5)/100 # Position relativ zur Mitte in m
B28_pos = (58.5-22.5)/100 # Position relativ zur Mitte in m
B29_pos = (60.5-22.5)/100 # Position relativ zur Mitte in m

# Jetzt die Hallsonde

Gauss_zu_Tesla = 10**(-4) # Faktor 10000 zur Umrechnung
Gauss_zu_mTesla = 10**(-1) # Faktor 10 zur Umrechnung
B_gauss_fehler = 0.5 # In Gauss
B_gauss_fehler = B_gauss_fehler*Gauss_zu_mTesla # In 10-3 Tesla

B30_gauss = 10 # B in Gauss # 22,5 cm
B31_gauss = 10 # B in Gauss
B32_gauss = 10 # B in Gauss
B33_gauss = 10 # B in Gauss
B34_gauss = 10 # B in Gauss
B35_gauss = 10 # B in Gauss
B36_gauss = 10 # B in Gauss
B37_gauss = 10 # B in Gauss
B38_gauss = 10 # B in Gauss
B39_gauss = 10 # B in Gauss
B40_gauss = 10 # B in Gauss # 32,5 cm
B41_gauss = 10 # B in Gauss
B42_gauss = 10 # B in Gauss
B43_gauss = 9 # B in Gauss # 35,5 cm
B44_gauss = 9 # B in Gauss
B45_gauss = 9 # B in Gauss
B46_gauss = 9 # B in Gauss
B47_gauss = 8 # B in Gauss
B48_gauss = 8 # B in Gauss
B49_gauss = 7 # B in Gauss
B50_gauss = 7 # B in Gauss
B51_gauss = 6 # B in Gauss # 43,5 cm
B52_gauss = 5 # B in Gauss
B53_gauss = 4 # B in Gauss
B54_gauss = 4 # B in Gauss
B55_gauss = 3 # B in Gauss
B56_gauss = 2 # B in Gauss
B57_gauss = 2 # B in Gauss
B58_gauss = 1 # B in Gauss # 50,5 cm

B30 = B30_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B31 = B31_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B32 = B32_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B33 = B33_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B34 = B34_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B35 = B35_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B36 = B36_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B37 = B37_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B38 = B38_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B39 = B39_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B40 = B40_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B41 = B41_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B42 = B42_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B43 = B43_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B44 = B44_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B45 = B45_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B46 = B46_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B47 = B47_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B48 = B48_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B49 = B49_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B50 = B50_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B51 = B51_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B52 = B52_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B53 = B53_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B54 = B54_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B55 = B55_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B56 = B56_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B57 = B57_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B58 = B58_gauss*Gauss_zu_mTesla # In 10^-3 Tesla

B30_pos = (22.5-22.5)/100 # Position relativ zur Mitte in m
B31_pos = (23.5-22.5)/100 # Position relativ zur Mitte in m
B32_pos = (24.5-22.5)/100 # Position relativ zur Mitte in m
B33_pos = (25.5-22.5)/100 # Position relativ zur Mitte in m
B34_pos = (26.5-22.5)/100 # Position relativ zur Mitte in m
B35_pos = (27.5-22.5)/100 # Position relativ zur Mitte in m
B36_pos = (28.5-22.5)/100 # Position relativ zur Mitte in m
B37_pos = (29.5-22.5)/100 # Position relativ zur Mitte in m
B38_pos = (30.5-22.5)/100 # Position relativ zur Mitte in m
B39_pos = (31.5-22.5)/100 # Position relativ zur Mitte in m
B40_pos = (32.5-22.5)/100 # Position relativ zur Mitte in m
B41_pos = (33.5-22.5)/100 # Position relativ zur Mitte in m
B42_pos = (34.5-22.5)/100 # Position relativ zur Mitte in m
B43_pos = (35.5-22.5)/100 # Position relativ zur Mitte in m
B44_pos = (36.5-22.5)/100 # Position relativ zur Mitte in m
B45_pos = (37.5-22.5)/100 # Position relativ zur Mitte in m
B46_pos = (38.5-22.5)/100 # Position relativ zur Mitte in m
B47_pos = (39.5-22.5)/100 # Position relativ zur Mitte in m
B48_pos = (40.5-22.5)/100 # Position relativ zur Mitte in m
B49_pos = (41.5-22.5)/100 # Position relativ zur Mitte in m
B50_pos = (42.5-22.5)/100 # Position relativ zur Mitte in m
B51_pos = (43.5-22.5)/100 # Position relativ zur Mitte in m
B52_pos = (44.5-22.5)/100 # Position relativ zur Mitte in m
B53_pos = (45.5-22.5)/100 # Position relativ zur Mitte in m
B54_pos = (46.5-22.5)/100 # Position relativ zur Mitte in m
B55_pos = (47.5-22.5)/100 # Position relativ zur Mitte in m
B56_pos = (48.5-22.5)/100 # Position relativ zur Mitte in m
B57_pos = (49.5-22.5)/100 # Position relativ zur Mitte in m
B58_pos = (50.5-22.5)/100 # Position relativ zur Mitte in m

# Für den Plot02 via Gnuplot

print("Für V14_plot02.dat via Gnuplot:")

print(" ") # Leerzeile

print("# Position[m] B[mT] B_fehler[mT] # Induktionspule")

print(B10_pos, B10, B_Pos_fehler, B10_fehler)
print(B11_pos, B11, B_Pos_fehler, B11_fehler)
print(B12_pos, B12, B_Pos_fehler, B12_fehler)
print(B13_pos, B13, B_Pos_fehler, B13_fehler)
print(B14_pos, B14, B_Pos_fehler, B14_fehler)
print(B15_pos, B15, B_Pos_fehler, B15_fehler)
print(B16_pos, B16, B_Pos_fehler, B16_fehler)
print(B17_pos, B17, B_Pos_fehler, B17_fehler)
print(B18_pos, B18, B_Pos_fehler, B18_fehler)
print(B19_pos, B19, B_Pos_fehler, B19_fehler)
print(B20_pos, B20, B_Pos_fehler, B20_fehler)
print(B21_pos, B21, B_Pos_fehler, B21_fehler)
print(B22_pos, B22, B_Pos_fehler, B22_fehler)
print(B23_pos, B23, B_Pos_fehler, B23_fehler)
print(B24_pos, B24, B_Pos_fehler, B24_fehler)
print(B25_pos, B25, B_Pos_fehler, B25_fehler)
print(B26_pos, B26, B_Pos_fehler, B26_fehler)
print(B27_pos, B27, B_Pos_fehler, B27_fehler)
print(B28_pos, B28, B_Pos_fehler, B28_fehler)
print(B29_pos, B29, B_Pos_fehler, B29_fehler)

print(" ") # Leerzeile

print("Für V14_plot03.dat via Gnuplot:")

print(" ") # Leerzeile

print("# Position[m] B[mT] B_fehler[mT] # Hallsonde lange Spule")

print(B30_pos, B30, B_Pos_fehler, B_gauss_fehler)
print(B31_pos, B31, B_Pos_fehler, B_gauss_fehler)
print(B32_pos, B32, B_Pos_fehler, B_gauss_fehler)
print(B33_pos, B33, B_Pos_fehler, B_gauss_fehler)
print(B34_pos, B34, B_Pos_fehler, B_gauss_fehler)
print(B35_pos, B35, B_Pos_fehler, B_gauss_fehler)
print(B36_pos, B36, B_Pos_fehler, B_gauss_fehler)
print(B37_pos, B37, B_Pos_fehler, B_gauss_fehler)
print(B38_pos, B38, B_Pos_fehler, B_gauss_fehler)
print(B39_pos, B39, B_Pos_fehler, B_gauss_fehler)
print(B40_pos, B40, B_Pos_fehler, B_gauss_fehler)
print(B41_pos, B41, B_Pos_fehler, B_gauss_fehler)
print(B42_pos, B42, B_Pos_fehler, B_gauss_fehler)
print(B43_pos, B43, B_Pos_fehler, B_gauss_fehler)
print(B44_pos, B44, B_Pos_fehler, B_gauss_fehler)
print(B45_pos, B45, B_Pos_fehler, B_gauss_fehler)
print(B46_pos, B46, B_Pos_fehler, B_gauss_fehler)
print(B47_pos, B47, B_Pos_fehler, B_gauss_fehler)
print(B48_pos, B48, B_Pos_fehler, B_gauss_fehler)
print(B49_pos, B49, B_Pos_fehler, B_gauss_fehler)
print(B50_pos, B50, B_Pos_fehler, B_gauss_fehler)
print(B51_pos, B51, B_Pos_fehler, B_gauss_fehler)
print(B52_pos, B52, B_Pos_fehler, B_gauss_fehler)
print(B53_pos, B53, B_Pos_fehler, B_gauss_fehler)
print(B54_pos, B54, B_Pos_fehler, B_gauss_fehler)
print(B55_pos, B55, B_Pos_fehler, B_gauss_fehler)
print(B56_pos, B56, B_Pos_fehler, B_gauss_fehler)
print(B57_pos, B57, B_Pos_fehler, B_gauss_fehler)
print(B58_pos, B58, B_Pos_fehler, B_gauss_fehler)

# Ende Auswertung Teil 1
# Out:
# Für V14_plot02.dat via Gnuplot:
#
# # Position[m] B[mT] B_fehler[mT] # Induktionspule
# 0.0 1.103578220660716 0.005 0.003484704652059499
# 0.02 1.1078053312238982 0.005 0.0034866408886484925
# 0.04 1.1078053312238982 0.005 0.0034866408886484925
# 0.06 1.0993511100975342 0.005 0.003482774693293072
# 0.08 1.0824426678448062 0.005 0.0034751178451316606
# 0.1 1.078215557281624 0.005 0.003473219431888794
# 0.12 1.0613071150288964 0.005 0.003465689285657214
# 0.14 1.0359444516498042 0.005 0.003454585723753615
# 0.16 0.9852191248916202 0.005 0.003433076692616892
# 0.18 0.9091311347543445 0.005 0.003402591116440846
# 0.2 0.8034533706747946 0.005 0.0033638862923973793
# 0.22 0.6301418375843327 0.005 0.0033099142101629944
# 0.24 0.44837608336750706 0.005 0.003266539069373093
# 0.26 0.3004272136561373 0.005 0.003241607264065436
# 0.28 0.1989765601397694 0.005 0.003230018901698849
# 0.3 0.14402412281840346 0.005 0.0032256347409118894
# 0.32 0.09329879606021951 0.005 0.0032227748840569126
# ...

# %%
# Jetzt die dicke Spule

B60_gauss = 9 # B in Gauss
B61_gauss = 8 # B in Gauss
B62_gauss = 8 # B in Gauss
B63_gauss = 8 # B in Gauss
B64_gauss = 8 # B in Gauss
B65_gauss = 8 # B in Gauss
B66_gauss = 8 # B in Gauss
B67_gauss = 7 # B in Gauss
B68_gauss = 7 # B in Gauss
B69_gauss = 7 # B in Gauss
B70_gauss = 6 # B in Gauss
B71_gauss = 6 # B in Gauss
B72_gauss = 5 # B in Gauss
B73_gauss = 5 # B in Gauss
B74_gauss = 4 # B in Gauss
B75_gauss = 4 # B in Gauss
B76_gauss = 3 # B in Gauss
B77_gauss = 3 # B in Gauss
B78_gauss = 3 # B in Gauss
B79_gauss = 2 # B in Gauss
B80_gauss = 2 # B in Gauss
B81_gauss = 1 # B in Gauss

B60 = B60_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B61 = B61_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B62 = B62_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B63 = B63_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B64 = B64_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B65 = B65_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B66 = B66_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B67 = B67_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B68 = B68_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B69 = B69_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B70 = B70_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B71 = B71_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B72 = B72_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B73 = B73_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B74 = B74_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B75 = B75_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B76 = B76_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B77 = B77_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B78 = B78_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B79 = B79_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B80 = B80_gauss*Gauss_zu_mTesla # In 10^-3 Tesla
B81 = B81_gauss*Gauss_zu_mTesla # In 10^-3 Tesla

B60_pos = (13.5-13.5)/100 # Position relativ zur Mitte in m
B61_pos = (14.5-13.5)/100 # Position relativ zur Mitte in m
B62_pos = (15.5-13.5)/100 # Position relativ zur Mitte in m
B63_pos = (16.5-13.5)/100 # Position relativ zur Mitte in m
B64_pos = (17.5-13.5)/100 # Position relativ zur Mitte in m
B65_pos = (18.5-13.5)/100 # Position relativ zur Mitte in m
B66_pos = (19.5-13.5)/100 # Position relativ zur Mitte in m
B67_pos = (20.5-13.5)/100 # Position relativ zur Mitte in m
B68_pos = (21.5-13.5)/100 # Position relativ zur Mitte in m
B69_pos = (22.5-13.5)/100 # Position relativ zur Mitte in m
B70_pos = (23.5-13.5)/100 # Position relativ zur Mitte in m
B71_pos = (24.5-13.5)/100 # Position relativ zur Mitte in m
B72_pos = (25.5-13.5)/100 # Position relativ zur Mitte in m
B73_pos = (26.5-13.5)/100 # Position relativ zur Mitte in m
B74_pos = (27.5-13.5)/100 # Position relativ zur Mitte in m
B75_pos = (28.5-13.5)/100 # Position relativ zur Mitte in m
B76_pos = (29.5-13.5)/100 # Position relativ zur Mitte in m
B77_pos = (30.5-13.5)/100 # Position relativ zur Mitte in m
B78_pos = (31.5-13.5)/100 # Position relativ zur Mitte in m
B79_pos = (32.5-13.5)/100 # Position relativ zur Mitte in m
B80_pos = (33.5-13.5)/100 # Position relativ zur Mitte in m
B81_pos = (34.5-13.5)/100 # Position relativ zur Mitte in m

# Für den Plot03 via Gnuplot

print("Für V14_plot03a.dat via Gnuplot:")

print(" ") # Leerzeile

print("# Position[m] B[mT] B_fehler[mT] # Hallsonde dicke Spule")

print(B60_pos, B60, B_Pos_fehler, B_gauss_fehler)
print(B61_pos, B61, B_Pos_fehler, B_gauss_fehler)
print(B62_pos, B62, B_Pos_fehler, B_gauss_fehler)
print(B63_pos, B63, B_Pos_fehler, B_gauss_fehler)
print(B64_pos, B64, B_Pos_fehler, B_gauss_fehler)
print(B65_pos, B65, B_Pos_fehler, B_gauss_fehler)
print(B66_pos, B66, B_Pos_fehler, B_gauss_fehler)
print(B67_pos, B67, B_Pos_fehler, B_gauss_fehler)
print(B68_pos, B68, B_Pos_fehler, B_gauss_fehler)
print(B69_pos, B69, B_Pos_fehler, B_gauss_fehler)
print(B70_pos, B70, B_Pos_fehler, B_gauss_fehler)
print(B71_pos, B71, B_Pos_fehler, B_gauss_fehler)
print(B72_pos, B72, B_Pos_fehler, B_gauss_fehler)
print(B73_pos, B73, B_Pos_fehler, B_gauss_fehler)
print(B74_pos, B74, B_Pos_fehler, B_gauss_fehler)
print(B75_pos, B75, B_Pos_fehler, B_gauss_fehler)
print(B76_pos, B76, B_Pos_fehler, B_gauss_fehler)
print(B77_pos, B77, B_Pos_fehler, B_gauss_fehler)
print(B78_pos, B78, B_Pos_fehler, B_gauss_fehler)
print(B79_pos, B79, B_Pos_fehler, B_gauss_fehler)
print(B80_pos, B80, B_Pos_fehler, B_gauss_fehler)
print(B81_pos, B81, B_Pos_fehler, B_gauss_fehler)

mu0 = 4*np.pi*10**(-7) # mu0 in N*A^-2

I = 500 # in 10^-3 Ampere
L1 = 0.45 # Länge der langen Spule in Metern
N1 = 832 # Windungszahl lange Spule
L2 = 0.27 # Länge der dicke Spule in Metern
N2 = 501 # Windungszahl dicken Spule

B_lang = mu0*I*N1/L1
B_dick = mu0*I*N2/L2

print(" ") # Leerzeile

print("Lange Spule, B theoretisch in mT:", B_lang)
print("Dicke Spule, B theoretisch in mT:", B_dick)

# Ende Auswertung Teil 2
# Out:
# Für V14_plot03a.dat via Gnuplot:
#
# # Position[m] B[mT] B_fehler[mT] # Hallsonde dicke Spule
# 0.0 0.9 0.005 0.05
# 0.01 0.8 0.005 0.05
# 0.02 0.8 0.005 0.05
# 0.03 0.8 0.005 0.05
# 0.04 0.8 0.005 0.05
# 0.05 0.8 0.005 0.05
# 0.06 0.8 0.005 0.05
# 0.07 0.7000000000000001 0.005 0.05
# 0.08 0.7000000000000001 0.005 0.05
# 0.09 0.7000000000000001 0.005 0.05
# 0.1 0.6000000000000001 0.005 0.05
# 0.11 0.6000000000000001 0.005 0.05
# 0.12 0.5 0.005 0.05
# 0.13 0.5 0.005 0.05
# 0.14 0.4 0.005 0.05
# 0.15 0.4 0.005 0.05
# 0.16 0.30000000000000004 0.005 0.05
# 0.17 0.30000000000000004 0.005 0.05
# 0.18 0.30000000000000004 0.005 0.05
# 0.19 0.2 0.005 0.05
# 0.2 0.2 0.005 0.05
# 0.21 0.1 0.005 0.05
#
# Lange Spule, B theoretisch in mT: 1.1616911501274259
# Dicke Spule, B theoretisch in mT: 1.165879940332212

# %%
# Beginn Auswertung Teil 3
# Jetzt die Ausmessung der Helmholtz-Spule

B_hs00 = 10 # In Gauss
B_hs01 = 12 # In Gauss
B_hs02 = 16 # In Gauss
B_hs03 = 20 # In Gauss
B_hs04 = 24 # In Gauss
B_hs05 = 28 # In Gauss
B_hs06 = 32 # In Gauss
B_hs07 = 34 # In Gauss
B_hs08 = 34 # In Gauss
B_hs09 = 34 # In Gauss
B_hs10 = 34 # In Gauss
B_hs11 = 34 # In Gauss
B_hs12 = 33 # In Gauss
B_hs13 = 31 # In Gauss
B_hs14 = 28 # In Gauss
B_hs15 = 23 # In Gauss
B_hs16 = 19 # In Gauss
B_hs17 = 15 # In Gauss
B_hs18 = 12 # In Gauss
B_hs19 = 9 # In Gauss
B_hs20 = 7 # In Gauss

B_hs00_pos = -10/100 # Position relativ zur Mitte in m
B_hs01_pos = -9/100 # Position relativ zur Mitte in m
B_hs02_pos = -8/100 # Position relativ zur Mitte in m
B_hs03_pos = -7/100 # Position relativ zur Mitte in m
B_hs04_pos = -6/100 # Position relativ zur Mitte in m
B_hs05_pos = -5/100 # Position relativ zur Mitte in m
B_hs06_pos = -4/100 # Position relativ zur Mitte in m
B_hs07_pos = -3/100 # Position relativ zur Mitte in m
B_hs08_pos = -2/100 # Position relativ zur Mitte in m
B_hs09_pos = -1/100 # Position relativ zur Mitte in m
B_hs10_pos = 0/100 # Position relativ zur Mitte in m
B_hs11_pos = 1/100 # Position relativ zur Mitte in m
B_hs12_pos = 2/100 # Position relativ zur Mitte in m
B_hs13_pos = 3/100 # Position relativ zur Mitte in m
B_hs14_pos = 4/100 # Position relativ zur Mitte in m
B_hs15_pos = 5/100 # Position relativ zur Mitte in m
B_hs16_pos = 6/100 # Position relativ zur Mitte in m
B_hs17_pos = 7/100 # Position relativ zur Mitte in m
B_hs18_pos = 8/100 # Position relativ zur Mitte in m
B_hs19_pos = 9/100 # Position relativ zur Mitte in m
B_hs20_pos = 10/100 # Position relativ zur Mitte in m

B_hs00 = B_hs00*Gauss_zu_mTesla # In 10^-3 Tesla
B_hs01 = B_hs01*Gauss_zu_mTesla # In 10^-3 Tesla
B_hs02 = B_hs02*Gauss_zu_mTesla # In 10^-3 Tesla
B_hs03 = B_hs03*Gauss_zu_mTesla # In 10^-3 Tesla
B_hs04 = B_hs04*Gauss_zu_mTesla # In 10^-3 Tesla
B_hs05 = B_hs05*Gauss_zu_mTesla # In 10^-3 Tesla
B_hs06 = B_hs06*Gauss_zu_mTesla # In 10^-3 Tesla
B_hs07 = B_hs07*Gauss_zu_mTesla # In 10^-3 Tesla
B_hs08 = B_hs08*Gauss_zu_mTesla # In 10^-3 Tesla
B_hs09 = B_hs09*Gauss_zu_mTesla # In 10^-3 Tesla
B_hs10 = B_hs10*Gauss_zu_mTesla # In 10^-3 Tesla
B_hs11 = B_hs11*Gauss_zu_mTesla # In 10^-3 Tesla
B_hs12 = B_hs12*Gauss_zu_mTesla # In 10^-3 Tesla
B_hs13 = B_hs13*Gauss_zu_mTesla # In 10^-3 Tesla
B_hs14 = B_hs14*Gauss_zu_mTesla # In 10^-3 Tesla
B_hs15 = B_hs15*Gauss_zu_mTesla # In 10^-3 Tesla
B_hs16 = B_hs16*Gauss_zu_mTesla # In 10^-3 Tesla
B_hs17 = B_hs17*Gauss_zu_mTesla # In 10^-3 Tesla
B_hs18 = B_hs18*Gauss_zu_mTesla # In 10^-3 Tesla
B_hs19 = B_hs19*Gauss_zu_mTesla # In 10^-3 Tesla
B_hs20 = B_hs00*Gauss_zu_mTesla # In 10^-3 Tesla

print("Für V14_plot04.dat via Gnuplot:")

print(" ") # Leerzeile

print("# Position[m] B[mT] B_fehler[mT] # Hallsonde Helmholtz-Spule")

print(B_hs00_pos, B_hs00, B_Pos_fehler, B_gauss_fehler)
print(B_hs01_pos, B_hs01, B_Pos_fehler, B_gauss_fehler)
print(B_hs02_pos, B_hs02, B_Pos_fehler, B_gauss_fehler)
print(B_hs03_pos, B_hs03, B_Pos_fehler, B_gauss_fehler)
print(B_hs04_pos, B_hs04, B_Pos_fehler, B_gauss_fehler)
print(B_hs05_pos, B_hs05, B_Pos_fehler, B_gauss_fehler)
print(B_hs06_pos, B_hs06, B_Pos_fehler, B_gauss_fehler)
print(B_hs07_pos, B_hs07, B_Pos_fehler, B_gauss_fehler)
print(B_hs08_pos, B_hs08, B_Pos_fehler, B_gauss_fehler)
print(B_hs09_pos, B_hs09, B_Pos_fehler, B_gauss_fehler)
print(B_hs10_pos, B_hs10, B_Pos_fehler, B_gauss_fehler)
print(B_hs11_pos, B_hs11, B_Pos_fehler, B_gauss_fehler)
print(B_hs12_pos, B_hs12, B_Pos_fehler, B_gauss_fehler)
print(B_hs13_pos, B_hs13, B_Pos_fehler, B_gauss_fehler)
print(B_hs14_pos, B_hs14, B_Pos_fehler, B_gauss_fehler)
print(B_hs15_pos, B_hs15, B_Pos_fehler, B_gauss_fehler)
print(B_hs16_pos, B_hs16, B_Pos_fehler, B_gauss_fehler)
print(B_hs17_pos, B_hs17, B_Pos_fehler, B_gauss_fehler)
print(B_hs18_pos, B_hs18, B_Pos_fehler, B_gauss_fehler)
print(B_hs19_pos, B_hs19, B_Pos_fehler, B_gauss_fehler)
print(B_hs20_pos, B_hs20, B_Pos_fehler, B_gauss_fehler)

mu0 = 4*np.pi*10**(-7) # mu0 in N*A^-2

I = 500 # in 10^-3 Ampere
D_hs = 0.1 # Durchmesser der Helmholtz-Spule in Metern
R_hs = D_hs/2 # Radius der Helmholtz-Spule in Metern
N_hs = 507 # Windungszahl Helmholtz-Spule

B_hs = 8*mu0*I*N_hs/(R_hs*np.sqrt(125))

print(" ") # Leerzeile

print("Lange Spule, B theoretisch in mT:", B_lang)
print("Dicke Spule, B theoretisch in mT:", B_dick)
print("Helmholtz-Spule, B theoretisch in mT:", B_hs)

# Ende Auswertung Teil 3
# Out:
# Für V14_plot04.dat via Gnuplot:
#
# # Position[m] B[mT] B_fehler[mT] # Hallsonde Helmholtz-Spule
# -0.1 1.0 0.005 0.05
# -0.09 1.2000000000000002 0.005 0.05
# -0.08 1.6 0.005 0.05
# -0.07 2.0 0.005 0.05
# -0.06 2.4000000000000004 0.005 0.05
# -0.05 2.8000000000000003 0.005 0.05
# -0.04 3.2 0.005 0.05
# -0.03 3.4000000000000004 0.005 0.05
# -0.02 3.4000000000000004 0.005 0.05
# -0.01 3.4000000000000004 0.005 0.05
# 0.0 3.4000000000000004 0.005 0.05
# 0.01 3.4000000000000004 0.005 0.05
# 0.02 3.3000000000000003 0.005 0.05
# 0.03 3.1 0.005 0.05
# 0.04 2.8000000000000003 0.005 0.05
# 0.05 2.3000000000000003 0.005 0.05
# 0.06 1.9000000000000001 0.005 0.05
# 0.07 1.5 0.005 0.05
# 0.08 1.2000000000000002 0.005 0.05
# 0.09 0.9 0.005 0.05
# 0.1 0.1 0.005 0.05
#
# Lange Spule, B theoretisch in mT: 1.1616911501274259
# Dicke Spule, B theoretisch in mT: 1.165879940332212
# Helmholtz-Spule, B theoretisch in mT: 4.558823767856189

# %%
# Anfang Auswertung Teil 4

#mu0 = 4*np.pi*10**(-7) # mu0 in N*A^-2

#L1 = 0.45 # Länge der langen Spule in Metern
#N1 = 832 # Windungszahl lange Spule
#L2 = 0.27 # Länge der dicke Spule in Metern
#N2 = 501 # Windungszahl dicken Spule
#D_hs = 0.1 # Durchmesser der Helmholtz-Spule in Metern
#R_hs = D_hs/2 # Radius der Helmholtz-Spule in Metern
#N_hs = 507 # Windungszahl Helmholtz-Spule

I_A = 0.5 # in Ampere

H_lang = I_A*N1/L1 # in A m^-1
H_dick = I_A*N2/L2 # in A m^-1
H_hs = 8*I_A*N_hs/(R_hs*np.sqrt(125)) # in A m^-1

mu0_IS = B11/(1000*H_lang) # in N*A^-2 = H m^-1
mu0_lang = B30/(1000*H_lang) # in N*A^-2 = H m^-1
mu0_dick = B60/(1000*H_dick) # in N*A^-2 = H m^-1
mu0_hs = B_hs09/(1000*H_hs) # in N*A^-2 = H m^-1

mu0_IS_fehler = B11_fehler/(1000*H_lang) # in N*A^-2 = H m^-1
mu0_lang_fehler = B_gauss_fehler/(1000*H_lang) # in N*A^-2 = H m^-1
mu0_dick_fehler = B_gauss_fehler/(1000*H_dick) # in N*A^-2 = H m^-1
mu0_hs_fehler = B_gauss_fehler/(1000*H_hs) # in N*A^-2 = H m^-1

# Gewichteter Mittelwert

Zaehler = mu0_IS/(mu0_IS_fehler**2) + mu0_lang/(mu0_lang_fehler**2) + mu0_dick/(mu0_dick_fehler**2) + mu0_hs/(mu0_hs_fehler**2)
Nenner = 1/(mu0_IS_fehler**2) + 1/(mu0_lang_fehler**2) + 1/(mu0_dick_fehler**2) + 1/(mu0_hs_fehler**2)

mu0_mess = Zaehler/Nenner
mu0_fehler = np.sqrt(1/Nenner)

print("Lange Spule vermessen per Induktionspule, B in mT:", B11)
print("Lange Spule vermessen per Induktionspule, B_fehler in mT:", B11_fehler)
print("Lange Spule vermessen per Hallsonde, B in mT:", B30)
print("Lange Spule vermessen per Hallsonde, B_fehler in mT:", B_gauss_fehler)
print("Dicke Spule vermessen per Hallsonde, B in mT:", B60)
print("Dicke Spule vermessen per Hallsonde, B_fehler in mT:", B_gauss_fehler)
print("Helmholtz-Spule vermessen per Hallsonde, B in mT:", B_hs09)
print("Helmholtz-Spule vermessen per Hallsonde, B_fehler in mT:", B_gauss_fehler)

print(" ") # Leerzeile

print("Lange Spule, H in A m^-1:", H_lang)
print("Lange Spule, H in A m^-1:", H_lang)
print("Dicke Spule, H in A m^-1:", H_dick)
print("Helmholtz-Spule, H in A m^-1:", H_hs)

print(" ") # Leerzeile

print("Lange Spule vermessen per Induktionspule, mu0 in N A^-2:", mu0_IS)
print("Lange Spule vermessen per Induktionspule, mu0_fehler in N A^-2:", mu0_IS_fehler)
print("Lange Spule vermessen per Hallsonde, mu0 in N A^-2:", mu0_lang)
print("Lange Spule vermessen per Hallsonde, mu0_fehler in N A^-2:", mu0_lang_fehler)
print("Dicke Spule vermessen per Hallsonde, mu0 in N A^-2:", mu0_dick)
print("Dicke Spule vermessen per Hallsonde, mu0_fehler in N A^-2:", mu0_dick_fehler)
print("Helmholtz-Spule vermessen per Hallsonde, mu0 in N A^-2:", mu0_hs)
print("Helmholtz-Spule vermessen per Hallsonde, mu0_fehler in N A^-2:", mu0_hs_fehler)

print(" ") # Leerzeile

print("mu0 gewichteter Mittelwert in N A^-2:", mu0_mess)
print("mu0_fehler gewichteter Mittelwert in N A^-2:", mu0_fehler)

print(" ") # Leerzeile

print("mu0 exakt in N A^-2:", mu0)

# Ende Auswertung Teil 4
# Out:
# Lange Spule vermessen per Induktionspule, B in mT: 1.1078053312238982
# Lange Spule vermessen per Induktionspule, B_fehler in mT: 0.0034866408886484925
# Lange Spule vermessen per Hallsonde, B in mT: 1.0
# Lange Spule vermessen per Hallsonde, B_fehler in mT: 0.05
# Dicke Spule vermessen per Hallsonde, B in mT: 0.9
# Dicke Spule vermessen per Hallsonde, B_fehler in mT: 0.05
# Helmholtz-Spule vermessen per Hallsonde, B in mT: 3.4000000000000004
# Helmholtz-Spule vermessen per Hallsonde, B_fehler in mT: 0.05
#
# Lange Spule, H in A m^-1: 924.4444444444445
# Lange Spule, H in A m^-1: 924.4444444444445
# Dicke Spule, H in A m^-1: 927.7777777777777
# Helmholtz-Spule, H in A m^-1: 3627.7966866956585
#
# Lange Spule vermessen per Induktionspule, mu0 in N A^-2: 1.1983471131027745e-06
# Lange Spule vermessen per Induktionspule, mu0_fehler in N A^-2: 3.771606730509186e-09
# Lange Spule vermessen per Hallsonde, mu0 in N A^-2: 1.0817307692307691e-06
# ...
