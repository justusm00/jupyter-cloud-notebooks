# %%
import numpy as np
u1=np.loadtxt("a2_daten_1.dat",float,usecols=0)
s1=np.loadtxt("a2_daten_1.dat",float,usecols=1)
ierror1=np.loadtxt("a2_daten_1.dat",float,usecols=2)

# %%
import numpy as np
import matplotlib.pyplot as plt


plt.figure(dpi=400)


plt.errorbar(u1, s1, ierror1, fmt='+', ecolor='g', color='r', capsize=3, label='Messdaten mit Fehler')

plt.grid()


plt.legend(loc='lower left')

# %%
import numpy as np

u2=np.loadtxt("a2_daten_2.dat",float,usecols=0)
s2=np.loadtxt("a2_daten_2.dat",float,usecols=1)
ierror2=np.loadtxt("a2_daten_2.dat",float,usecols=2)


import matplotlib.pyplot as plt


plt.figure(dpi=400)


plt.errorbar(u2, s2, ierror2, fmt='+', ecolor='g', color='r', capsize=3, label='Messdaten mit Fehler')

plt.grid()


plt.legend(loc='lower left')

# %%
import numpy as np

u3=np.loadtxt("a2_daten_3.dat",float,usecols=0)
s3=np.loadtxt("a2_daten_3.dat",float,usecols=1)
ierror3=np.loadtxt("a2_daten_3.dat",float,usecols=2)


import matplotlib.pyplot as plt


plt.figure(dpi=400)

plt.errorbar(u1, s1, ierror1, fmt='+', ecolor='g', color='r', capsize=3, label='Messdaten mit Fehler')

plt.errorbar(u, s2, ierror2, fmt='.', ecolor='g', color='g', capsize=3, label='Messdaten mit Fehler')

plt.errorbar(u3, s3, ierror3, fmt='.', ecolor='b', color='b', capsize=3, label='Messdaten mit Fehler')


plt.grid()


plt.legend(loc='upper left')
