# %%
import numpy as np
import matplotlib.pyplot as plt

n_polym=20000
N=32
L=10
V=10*3*3
Nbar=n_polym/V
lam=0.00935
a=L*N/(lam*Nbar)
def phi0(r):
    return 1/(2+a*r)

rates_ue=np.array([0.0005,0.001,0.002,0.003,0.004,0.005,0.006,0.007,0.008,0.009])
phia=np.array([0.4699174,  0.4699535 , 0.42521674 ,0.40538024, 0.38354855 ,0.36711796,
 0.34357566 ,0.33226296, 0.30909109 ,0.29206139])

print(a)

r = np.linspace(0,0.008,1000)
plt.plot(r,phi0(r))
plt.plot(rates_ue,phia)
print(a/746.15)
# Out:
# 154.01069518716577
# 0.20640715028769788
