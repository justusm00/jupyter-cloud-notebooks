# %%
import numpy as np
import matplotlib.pyplot as plt


t,vcst = np.loadtxt("clo_64w_250K.dt3",usecols=(1,11)).T

plt.figure(dpi=150)
plt.title("Restraining potential")
plt.xlabel("$t$ [fs]")
plt.ylabel("$V_{cst}$ [kcal/mol]")
plt.plot(t,vcst,lw=1)
plt.savefig("vcst.pdf")
