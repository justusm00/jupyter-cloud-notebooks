# %%
import numpy as np
import matplotlib.pyplot as plt


t,vcst = np.loadtxt("clo_32w_250K.dt3",usecols=(1,11)).T

plt.figure(dpi=150)
plt.title("Restraining potential, $R_{max}$=15$\AA$")
plt.xlabel("$t$ [fs]")
plt.ylabel("$V_{cst}$ [kcal/mol]")
plt.plot(t,vcst,lw=1)
plt.savefig("clo_32w_250K_vcst.png")
